# %%
import cut_telephone as cut_telephone

  
# 0黑色，255白色
# 11,12,13
file_name = "zto/2.jpg"
img,cut = cut_telephone.rotate_(file_name,(1430,895),(280,30),30,draw=False,display=True)
print(cut)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [151 255 203 ... 255 255 255]
#  [  0  56   0 ... 255 255 255]
#  [  0   0   0 ... 255 255 255]]
