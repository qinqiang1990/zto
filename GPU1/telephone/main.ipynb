# %%
# coding:utf-8

import matplotlib.pyplot as plt
import cv2
import os
import main as main
import common as common
# %matplotlib inline
# 11 13
# main.main_(file_path = "../zto/13.jpg")
img = main.read_("./result/3_chosen.jpg", shrink=0.3)
img = common.canny_(img)

plt.figure(figsize=(5,5))
plt.imshow(img)
plt.show()

# %%
# main.main_(file_path = "../zto/11.jpg")
img = main.read_("./result/3_chosen.jpg", shrink=0.3)
img = common.canny_(img)

plt.figure(figsize=(5,5))
plt.imshow(img)
plt.show()

# %%
import cv2
cap = cv2.VideoCapture('D:/workspace/qinq/workspace/video.mp4')
while(cap.isOpened()):  
    ret, frame = cap.read() 
    cv2.imshow('image', frame)  
    k = cv2.waitKey(20) 
    #q键退出
    if (k & 0xff == ord('q')):  
        break  
cap.release()
cv2.destroyAllWindows()
